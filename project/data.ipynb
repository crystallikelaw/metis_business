# %%
import pandas as pd

df = pd.read_csv('US_Accidents_Dec21_updated.csv', parse_dates=['Start_Time'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.tail()
# Out:
#                 ID  Severity          Start_Time             End_Time  \
# 2845337  A-2845338         2 2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat  Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# 2845337   34.00248 -117.37936  33.99888 -117.37094         0.543
# 2845338   32.76696 -117.14806  32.76555 -117.15363         0.338
# 2845339   33.77545 -117.84779  33.77740 -117.85727         0.561
# 2845340   33.99246 -118.40302  33.98311 -118.39565         0.772
# 2845341   34.13393 -117.23092  34.13736 -117.23934         0.537
#
#                                                Description  ...  Roundabout  \
# ...

# %%
df2 = df[(pd.to_datetime('7/1/2021', dayfirst=True) >= df.Start_Time) & ( df.Start_Time >= pd.to_datetime('1/1/2021'))]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18387 entries, 439760 to 2069159
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     18387 non-null  object
#  1   Severity               18387 non-null  int64
#  2   Start_Time             18387 non-null  datetime64[ns]
#  3   End_Time               18387 non-null  object
#  4   Start_Lat              18387 non-null  float64
#  5   Start_Lng              18387 non-null  float64
#  6   End_Lat                18387 non-null  float64
#  7   End_Lng                18387 non-null  float64
#  8   Distance(mi)           18387 non-null  float64
#  9   Description            18387 non-null  object
#  10  Number                 8792 non-null   float64
#  11  Street                 18387 non-null  object
#  12  Side                   18387 non-null  object
#  13  City                   18387 non-null  object
# ...

# %%
df.Start_Time.max()
# Out:
# Timestamp('2021-12-31 23:30:00')

# %%
df2.Start_Time.min()
# Out:
# Timestamp('2021-01-01 00:00:00')

# %%
df2.to_csv('finalworkingdata2.csv')
